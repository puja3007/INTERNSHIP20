# %% [markdown]
# # Write a python program to display all the header tags from‘en.wikipedia.org/wiki/Main_Page’.

# %%
from bs4 import BeautifulSoup
import requests

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen('https://en.wikipedia.org/wiki/Main_Page')
bs = BeautifulSoup(html, "html.parser")
titles = bs.find_all(['h1', 'h2','h3','h4','h5','h6'])
print('List all the header tags :', *titles, sep='\n\n')
# Out:
# List all the header tags :
#
# <h1 class="firstHeading" id="firstHeading">Main Page</h1>
#
# <h2 class="mp-h2" id="mp-tfa-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="From_today's_featured_article">From today's featured article</span></h2>
#
# <h2 class="mp-h2" id="mp-dyk-h2"><span class="mw-headline" id="Did_you_know_...">Did you know ...</span></h2>
#
# <h2 class="mp-h2" id="mp-itn-h2"><span class="mw-headline" id="In_the_news">In the news</span></h2>
#
# <h2 class="mp-h2" id="mp-otd-h2"><span class="mw-headline" id="On_this_day">On this day</span></h2>
#
# <h2 class="mp-h2" id="mp-tfp-h2"><span id="Today.27s_featured_picture"></span><span class="mw-headline" id="Today's_featured_picture">Today's featured picture</span></h2>
#
# <h2 class="mp-h2" id="mp-other"><span class="mw-headline" id="Other_areas_of_Wikipedia">Other areas of Wikipedia</span></h2>
#
# ...

# %% [markdown]
# # Write a python program to display IMDB’s Top rated  movies’ data (i.e. Name, IMDB rating, Year

# %%
from bs4 import BeautifulSoup
import requests
import re


url = 'http://www.imdb.com/chart/top'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')

movies = soup.select('td.titleColumn')
links = [a.attrs.get('href') for a in soup.select('td.titleColumn a')]
crew = [a.attrs.get('title') for a in soup.select('td.titleColumn a')]
ratings = [b.attrs.get('data-value') for b in soup.select('td.posterColumn span[name=ir]')]
votes = [b.attrs.get('data-value') for b in soup.select('td.ratingColumn strong')]

imdb = []

# Store each item into dictionary (data), then put those into a list (imdb)
for index in range(0, len(movies)):
    # Seperate movie into: 'place', 'title', 'year'
    movie_string = movies[index].get_text()
    movie = (' '.join(movie_string.split()).replace('.', ''))
    movie_title = movie[len(str(index))+1:-7]
    year = re.search('\((.*?)\)', movie_string).group(1)
    place = movie[:len(str(index))-(len(movie))]
    data = {"movie_title": movie_title,
            "year": year,
            "place": place,
            "star_cast": crew[index],
            "rating": ratings[index],
            "vote": votes[index],
            "link": links[index]}
    imdb.append(data)

for item in imdb:
    print(item['place'], '-', item['movie_title'], '('+item['year']+') -', item["rating"])
# Out:
# 1 - The Shawshank Redemption (1994) - 9.220540233311239
# 2 - The Godfather (1972) - 9.147267197407677
# 3 - The Godfather: Part II (1974) - 8.980488378035394
# 4 - The Dark Knight (2008) - 8.973024989715224
# 5 - 12 Angry Men (1957) - 8.939108654713836
# 6 - Schindler's List (1993) - 8.911127794273707
# 7 - The Lord of the Rings: The Return of the King (2003) - 8.888278973032225
# 8 - Pulp Fiction (1994) - 8.83608545301329
# 9 - Il buono, il brutto, il cattivo (1966) - 8.786404351542808
# 1 -  The Lord of the Rings: The Fellowship of the Ring (2001) - 8.778490267564422
# 11 - Fight Club (1999) - 8.7523577752221
# 12 - Forrest Gump (1994) - 8.743860603418314
# 13 - Inception (2010) - 8.714641349103504
# 14 - The Lord of the Rings: The Two Towers (2002) - 8.701995534905658
# 15 - Star Wars: Episode V - The Empire Strikes Back (1980) - 8.69484018751125
# 16 - The Matrix (1999) - 8.645259910980915
# 17 - Goodfellas (1990) - 8.643781409372687
# ...

# %%
from bs4 import BeautifulSoup
import requests
import re


url = 'https://www.imdb.com/india/top-rated-indian-movies/'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')

movies = soup.select('td.titleColumn')
links = [a.attrs.get('href') for a in soup.select('td.titleColumn a')]
crew = [a.attrs.get('title') for a in soup.select('td.titleColumn a')]
ratings = [b.attrs.get('data-value') for b in soup.select('td.posterColumn span[name=ir]')]
votes = [b.attrs.get('data-value') for b in soup.select('td.ratingColumn strong')]

imdb = []

# Store each item into dictionary (data), then put those into a list (imdb)
for index in range(0, len(movies)):
    # Seperate movie into: 'place', 'title', 'year'
    movie_string = movies[index].get_text()
    movie = (' '.join(movie_string.split()).replace('.', ''))
    movie_title = movie[len(str(index))+1:-7]
    year = re.search('\((.*?)\)', movie_string).group(1)
    place = movie[:len(str(index))-(len(movie))]
    data = {"movie_title": movie_title,
            "year": year,
            "place": place,
            "star_cast": crew[index],
            "rating": ratings[index],
            "vote": votes[index],
            "link": links[index]}
    imdb.append(data)

for item in imdb:
    print(item['place'], '-', item['movie_title'], '('+item['year']+') -', item["rating"])
# Out:
# 1 - Nayakan (1987) - 8.494749082493176
# 2 - Anbe Sivam (2003) - 8.483185308711482
# 3 - Pariyerum Perumal (2018) - 8.480850826397496
# 4 - C/o Kancharapalem (2018) - 8.468740077296841
# 5 - Golmaal (1979) - 8.467004686430663
# 6 - Manichitrathazhu (1993) - 8.461161683192962
# 7 - Kireedam (1989) - 8.460215335060544
# 8 - Apur Sansar (1959) - 8.456635204158445
# 9 - Natsamrat (2016) - 8.436280026567204
# 1 -  96 (2018) - 8.429029138618345
# 11 - Pather Panchali (1955) - 8.416990664774934
# 12 - Kumbalangi Nights (2019) - 8.414947623808816
# 13 - Thevar Magan (1992) - 8.414573244029633
# 14 - Black Friday (2004) - 8.41112074667696
# 15 - Soorarai Pottru (2020) - 8.364421300899837
# 16 - Visaaranai (2015) - 8.360884006847883
# 17 - 3 Idiots (2009) - 8.351004416437787
# 18 - #Home (2021) - 8.342933928315857
# 19 - Jersey (2019) - 8.341946211632695
# 20 - Taare Zameen Par (2007) - 8.32928812005297
# 21 - Drishyam 2 (2021) - 8.32286236287206
# 22 - Asuran (2019) - 8.319752542246743
# ...

# %% [markdown]
# # Write a python program to scrap book name, author name, genre and book review of any 5 books from
# ‘www.bookpage.com’

# %%
from bs4 import BeautifulSoup
import requests
import re

url = "https://bookpage.com/reviews"
response= requests.get(url)
soup= BeautifulSoup(response.text, "lxml")

book_title=soup.find_all("h4",class_="italic",limit=5)
book_title
kitab_title=[]

for i in book_title:
    kitab_title.append(i.text.strip())
kitab_title
# Out:
# ['★ A Calling for Charlie Barnes',
#  "Playing the Cards You're Dealt",
#  "Please Don't Sit on My Bed in Your Outside Clothes",
#  'Horseman',
#  '★ Cloud Cuckoo Land']

# %%
authors=soup.find_all("p",class_="sans bold",limit=5)
authors
authors_name=[]
for i in authors:
    authors_name.append(i.text.strip())
authors_name
# Out:
# ['Joshua Ferris',
#  'Varian Johnson',
#  'Phoebe Robinson',
#  'Christina Henry',
#  'Anthony Doerr']

# %%
genre=soup.find_all("p",class_="excerpt",limit=5)
genre
genres=[]
for i in genre:
    genres.append(i.text.strip())
genres
# Out:
# ['Joshua Ferris’ control of his narrative is impeccable, but that doesn’t mean readers shouldn’t be prepared for frequent wicked curveballs.',
#  '',
#  'Not only are Phoebe Robinson’s essays super funny, they’re also enlightening and thought-provoking, dotted with hits of poetry, anger and revelation.',
#  '',
#  'Sorrow and violence play large roles in the latest novel from Anthony Doerr, but so does tenderness.']

# %%
import pandas as pd
books=pd.DataFrame({})
books["book_title"]=kitab_title
books["authors"]=authors
books["genre"]=genres

# %%
books
# Out:
#                                           book_title                authors  \
# 0                     ★ A Calling for Charlie Barnes    [\nJoshua Ferris\n]
# 1                     Playing the Cards You're Dealt   [\nVarian Johnson\n]
# 2  Please Don't Sit on My Bed in Your Outside Clo...  [\nPhoebe Robinson\n]
# 3                                           Horseman  [\nChristina Henry\n]
# 4                                ★ Cloud Cuckoo Land    [\nAnthony Doerr\n]
#
#                                                genre
# 0  Joshua Ferris’ control of his narrative is imp...
# 1
# 2  Not only are Phoebe Robinson’s essays super fu...
# 3
# 4  Sorrow and violence play large roles in the la...

# %% [markdown]
# Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.

# %%
from bs4 import BeautifulSoup
import requests
import re
url = "https://www.icc-cricket.com/rankings/mens/team-rankings/odi"
response= requests.get(url)
soup= BeautifulSoup(response.text, "lxml")

countries=soup.find_all("span",class_="u-show-phablet",limit=10)
countries

country_name=[]
for i in countries:
    country_name.append(i.text)
country_name
# Out:
# ['NZ', 'ENG', 'AUS', 'IND', 'SA', 'PAK', 'BAN', 'WI', 'SL', 'AFG']

# %%
ratings=soup.find_all("td",class_="table-body__cell u-text-right rating",limit=10)
ratings

rating_no=[]
for i in ratings:
    rating_no.append(i.text)
rating_no
# Out:
# ['119', '116', '113', '98', '93', '91', '84', '83', '62', '48']

# %%
matches=soup.find_all("td",class_="table-body__cell u-center-text",limit=20)
matches


match_no=[]
for i in matches:
    match_no.append(i.text.strip())
match_no
# Out:
# ['32',
#  '3,793',
#  '28',
#  '3,244',
#  '32',
#  '3,624',
#  '25',
#  '2,459',
#  '27',
#  '2,524',
#  '30',
#  '2,740',
#  '30',
#  '2,523',
#  '32',
#  '2,657',
#  '17',
#  '1,054',
#  '7',
#  '336']

# %%
import pandas as pd
MATCH=pd.DataFrame({})
MATCH["country_name"]=countries
MATCH["rating_no"]=ratings

# %%
MATCH
# Out:
#   country_name rating_no
# 0         [NZ]     [119]
# 1        [ENG]     [116]
# 2        [AUS]     [113]
# 3        [IND]      [98]
# 4         [SA]      [93]
# 5        [PAK]      [91]
# 6        [BAN]      [84]
# 7         [WI]      [83]
# 8         [SL]      [62]
# 9        [AFG]      [48]

# %% [markdown]
# Top 10 ODI Batsmen in men along with the records of their team and rating.

# %%
from bs4 import BeautifulSoup
import requests
import re
url = "https://www.icc-cricket.com/rankings/mens/player-rankings/odi"
response= requests.get(url)
soup= BeautifulSoup(response.text, "lxml")



men=soup.find_all("td",class_="table-body__cell name",limit=9)
men

top_ten=[]
for i in men:
    top_ten.append(i.text.strip())
top_ten
top_ten.insert(0,"BABAR AZAM")



top_ten



ratings=[873,844,813,801,779,775,762,758,754,747]
ratings




import pandas as pd
ds=pd.DataFrame({})
ds["top_ten"]=top_ten
ds["ratings"]=ratings




ds
# Out:
#            top_ten  ratings
# 0       BABAR AZAM      873
# 1      Virat Kohli      844
# 2     Rohit Sharma      813
# 3      Ross Taylor      801
# 4      Aaron Finch      779
# 5   Jonny Bairstow      775
# 6     David Warner      762
# 7        Shai Hope      758
# 8  Kane Williamson      754
# 9  Quinton de Kock      747

# %% [markdown]
# Top 10 women’s ODI players along with the records of their team and rating.

# %%
from bs4 import BeautifulSoup
import requests
import re
url = "https://www.icc-cricket.com/rankings/womens/player-rankings/odi"
response= requests.get(url)
soup= BeautifulSoup(response.text, "lxml")

women=soup.find_all("td",class_="table-body__cell name",limit=9)
women

top_tenwomen=[]
for i in women:
    top_tenwomen.append(i.text.strip())
top_tenwomen

# %%
top_tenwomen.insert(0,"LIZELLE LEE")

# %%
top_tenwomen
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ecdf18d0e6de> in <module>
# ----> 1 top_tenwomen
#
# NameError: name 'top_tenwomen' is not defined

# %%
ratings_women=[761,750,738,728,717,710,699,690,674,672]
ratings_women
# Out:
# [761, 750, 738, 728, 717, 710, 699, 690, 674, 672]

# %%
import pandas as pd
ds=pd.DataFrame({})
ds["top_tenwomen"]=top_tenwomen
ds["ratings_women"]=ratings_women
ds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d4f80269bc01> in <module>
#       1 import pandas as pd
#       2 ds=pd.DataFrame({})
# ----> 3 ds["top_tenwomen"]=top_tenwomen
#       4 ds["ratings_women"]=ratings_women
#       5 ds
#
# NameError: name 'top_tenwomen' is not defined

# %% [markdown]
# Top 10 women’s ODI all-rounder along with the records of their team and rating.

# %%
from bs4 import BeautifulSoup
import requests
import re
url = "https://www.icc-cricket.com/rankings/womens/player-rankings/odi"
response= requests.get(url)
soup= BeautifulSoup(response.text, "lxml")

women_allrounder=soup.find_all("td",class_="table-body__cell name",limit=27)
women_allrounder



allrounder=[]
for i in women_allrounder:
    allrounder.append(i.text.strip())
allrounder

# %%
NEW_LIST=allrounder[19:27]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-0c69f2393c79> in <module>
# ----> 1 NEW_LIST=allrounder[19:27]
#
# NameError: name 'allrounder' is not defined

# %%
NEW_LIST.insert(0,"MARIZANNE KAPP")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-5e6acdf05aff> in <module>
# ----> 1 NEW_LIST.insert(0,"MARIZANNE KAPP")
#
# NameError: name 'NEW_LIST' is not defined

# %%
NEW_LIST
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-30ae4af1a86f> in <module>
# ----> 1 NEW_LIST
#
# NameError: name 'NEW_LIST' is not defined

# %%
RATINGS_ALL=[384,372,365,322,299,275,274,272,251]
RATINGS_ALL
# Out:
# [384, 372, 365, 322, 299, 275, 274, 272, 251]

# %%
import pandas as pd
AR=pd.DataFrame({})
AR["NEW_LIST"]=NEW_LIST
AR["RATINGS_ALL"]=RATINGS_ALL
AR
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-99257b9b7c23> in <module>
#       1 import pandas as pd
#       2 AR=pd.DataFrame({})
# ----> 3 AR["NEW_LIST"]=NEW_LIST
#       4 AR["RATINGS_ALL"]=RATINGS_ALL
#       5 AR
#
# NameError: name 'NEW_LIST' is not defined

# %% [markdown]
# Write a python program to scrape fresher job listings from ‘https://internshala.com/’.

# %%
from bs4 import BeautifulSoup
import requests
import re
url = "https://internshala.com/fresher-jobs"
response= requests.get(url)
soup= BeautifulSoup(response.text, "lxml")


JOBS=soup.find_all("div",class_="heading_4_5 profile")
JOBS



JOB=[]
for i in JOBS:
    JOB.append(i.text.strip())
JOB


COMPANIES=soup.find_all("div",class_="heading_6 company_name")
COMPANIES


comp_name=[]
for i in COMPANIES:
    comp_name.append(i.text.strip())
comp_name
import pandas as pd
kaam=pd.DataFrame({})
kaam["JOBS"]=JOB
kaam["COMPANIES"]=comp_name
kaam
# Out:
#                                              JOBS  \
# 0                      Management Trainee - Sales
# 1             Backend Developer - Java/Spring MVC
# 2             Online Robotics & Coding Instructor
# 3                   Cyber Security Junior Analyst
# 4                Modeling And Simulation Engineer
# 5                  Business Development Executive
# 6                                  Content Writer
# 7                      Customer Support Executive
# 8                       Corporate Sales Associate
# 9                              Front-End Engineer
# 10                     Full Stack Engineer (MERN)
# 11                                 Content Writer
# 12                      Associate Project Manager
# 13                    Researcher & Content Writer
# 14  Senior Copywriter - Media Query Pitching Team
# 15          Educational Counselor And Coordinator
# 16                              Software Engineer
# 17                       Junior Software Engineer
# ...

# %%
from bs4 import BeautifulSoup
import requests
import re
url = "https://internshala.com/fresher-jobs"
response= requests.get(url)
soup= BeautifulSoup(response.text, "lxml")

apply=soup.find_all("span",class_="start_immediately_mobile")
apply



apply_date=[]
for i in apply:
    apply_date.append(i.text.strip())
apply_date
# Out:
# ['Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts',
#  'Starts']

# %%
import pandas as pd
kaam=pd.DataFrame({})
kaam["JOBS"]=JOB
kaam["COMPANIES"]=comp_name
kaam["apply"]=apply_date
kaam
